# %% [raw]
# ---
# skip_showdoc: true
# skip_exec: true
# ---

# %% [markdown]
# # Plot

# %% [markdown]
# ### Setup

# %%
from katlas.core import *
from katlas.plot import *

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
# %config InlineBackend.figure_format = 'svg'
# sns.set(rc={"figure.dpi":300, 'savefig.dpi':300})
# sns.set_context('notebook')
# sns.set_style("ticks")

# %% [markdown]
# ### Data

# %%
ks = Data.get_ks_dataset()

# %%
ks_k = ks[ks.kinase_uniprot=='P00519']

# %%
pssm = get_prob(ks_k,'site_seq')

# %% [markdown]
# ## Plot

# %%
plot_heatmap(pssm,include_zero=False);

# %%
plot_logo(pssm,'kinase')

# %%
plot_logo_heatmap(pssm,'kinase')
