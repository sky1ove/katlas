# %% [markdown]
# ## CDDM umap

# %%
import pandas as pd
from katlas.data import *

# %%
df = pd.read_parquet("out/CDDM_pssms.parquet")

# %%
info = Data.get_kinase_info()

# %%
info = info[info.pseudo=='0'].copy()

# %%
info['kinase_id'] = info.uniprot + "_" + info.kinase

# %%
from katlas.plot import *

# %%
hue = info.set_index('kinase_id')['modi_group']

# %%
plot_cluster??
# Out:
# Signature:
# plot_cluster(
#     df: pandas.core.frame.DataFrame,
#     method: str = 'pca',
#     hue: str = None,
#     complexity: int = 30,
#     palette: str = 'tab20',
#     legend: bool = False,
#     name_list=None,
#     seed: int = 123,
#     s: int = 50,
#     legend_title: str = None,
#     **kwargs,
# )
# Source:
# def plot_cluster(
#     df: pd.DataFrame,  # a dataframe of values that is waited for dimensionality reduction
#     method: str = 'pca',  # dimensionality reduction method, choose from pca, umap, and tsne
#     hue: str = None,  # colname of color
#     complexity: int = 30,  # this argument does not affect pca but others; recommend 30 for tsne, 15 for umap
#     palette: str = 'tab20',  # color scheme, could be tab10 if less categories
#     legend: bool = False,  # whether or not add the legend on the side
#     name_list=None,  # a list of names to annotate each dot in the plot
#     seed: int = 123,  # seed for dimensionality reduction
# ...

# %%
from matplotlib import pyplot as plt

# %%
plot_cluster(df,method='umap',
             hue=hue,
             legend=True,
             complexity=6,
             min_dist=0.5,
             palette=group_color,
             legend_title='Group'
             )
save_svg('fig/CDDM_umap.svg')
# Out:
# /Users/icai/git/katlas/.venv/lib/python3.13/site-packages/logomaker/../umap/umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(

# %%
plot_cluster
# Out:
# Signature:
# plot_cluster(
#     df: pandas.core.frame.DataFrame,
#     method: str = 'pca',
#     hue: str = None,
#     complexity: int = 30,
#     palette: str = 'tab20',
#     legend: bool = False,
#     name_list=None,
#     seed: int = 123,
#     s: int = 50,
#     legend_title: str = None,
#     **kwargs,
# )
# Docstring:
# Given a dataframe of values, plot it in 2D.
# The method could be 'pca', 'tsne', or 'umap'.
# File:      ~/git/katlas/katlas/plot.py
# Type:      function

# %%
info.set

# %%
df
# Out:
#                    -20P      -20G      -20A      -20C      -20S      -20T  \
# index
# P12931_SRC     0.054538  0.081380  0.060077  0.012356  0.036216  0.032382
# P29320_EPHA3   0.044276  0.088013  0.065335  0.008639  0.037797  0.036717
# P07332_FES     0.047231  0.082519  0.070575  0.011401  0.034745  0.039088
# Q16288_NTRK3   0.044444  0.074644  0.074074  0.017094  0.033048  0.035328
# Q9UM73_ALK     0.045748  0.079765  0.073314  0.018182  0.032845  0.035191
# ...                 ...       ...       ...       ...       ...       ...
# Q15746_SMMLCK  0.078947  0.052632  0.078947  0.026316  0.052632  0.026316
# Q01973_ROR1    0.097561  0.097561  0.024390  0.000000  0.024390  0.146341
# P15056_BRAF    0.095238  0.071429  0.047619  0.000000  0.095238  0.047619
# O14976_GAK     0.075000  0.075000  0.175000  0.000000  0.025000  0.025000
# Q6P0Q8_MAST2   0.046512  0.116279  0.069767  0.000000  0.023256  0.069767
#
#                    -20V      -20I      -20L      -20M  ...       20H  \
# ...
